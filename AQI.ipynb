# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('city_day.csv')
df.head()
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
df.shape
# Out:
# (29531, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  object
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 3.6+ MB

# %%
df.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %%
df.drop(['Xylene'],axis = 1,inplace = True)
df.head(2)
# Out:
#         City        Date  PM2.5  PM10    NO    NO2    NOx  NH3    CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN  0.92  18.22  17.15  NaN  0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN  0.97  15.69  16.46  NaN  0.97  24.55
#
#        O3  Benzene  Toluene  AQI AQI_Bucket
# 0  133.36     0.00     0.02  NaN        NaN
# 1   34.06     3.68     5.50  NaN        NaN

# %%
df['City'].unique()
# Out:
# array(['Ahmedabad', 'Aizawl', 'Amaravati', 'Amritsar', 'Bengaluru',
#        'Bhopal', 'Brajrajnagar', 'Chandigarh', 'Chennai', 'Coimbatore',
#        'Delhi', 'Ernakulam', 'Gurugram', 'Guwahati', 'Hyderabad',
#        'Jaipur', 'Jorapokhar', 'Kochi', 'Kolkata', 'Lucknow', 'Mumbai',
#        'Patna', 'Shillong', 'Talcher', 'Thiruvananthapuram',
#        'Visakhapatnam'], dtype=object)

# %%
df.City.value_counts().values
# Out:
# array([2009, 2009, 2009, 2009, 2009, 2009, 2006, 1858, 1679, 1462, 1221,
#        1169, 1114, 1112,  951,  938,  925,  814,  502,  386,  310,  304,
#         289,  162,  162,  113], dtype=int64)

# %%
df.City.value_counts().index
# Out:
# Index(['Ahmedabad', 'Delhi', 'Mumbai', 'Bengaluru', 'Lucknow', 'Chennai',
#        'Hyderabad', 'Patna', 'Gurugram', 'Visakhapatnam', 'Amritsar',
#        'Jorapokhar', 'Jaipur', 'Thiruvananthapuram', 'Amaravati',
#        'Brajrajnagar', 'Talcher', 'Kolkata', 'Guwahati', 'Coimbatore',
#        'Shillong', 'Chandigarh', 'Bhopal', 'Ernakulam', 'Kochi', 'Aizawl'],
#       dtype='object', name='City')

# %%
df1 = df[df['City'].isin(['Delhi', 'Bengaluru', 'Kolkata'])]
df1.head()
# Out:
#            City        Date  PM2.5  PM10     NO    NO2    NOx    NH3     CO  \
# 4294  Bengaluru  2015-01-01    NaN   NaN   3.26  17.33  10.88  20.36   0.33
# 4295  Bengaluru  2015-01-02    NaN   NaN   6.05  19.73  14.14  23.74   1.35
# 4296  Bengaluru  2015-01-03    NaN   NaN  11.91  19.88  20.72   4.32  17.40
# 4297  Bengaluru  2015-01-04    NaN   NaN   7.45  21.61  16.88   0.87   5.05
# 4298  Bengaluru  2015-01-05    NaN   NaN   9.52  22.17  21.76  31.38   1.83
#
#         SO2     O3  Benzene  Toluene  AQI AQI_Bucket
# 4294   3.54  10.73     0.56     4.64  NaN        NaN
# 4295   3.97  22.77     0.65     5.31  NaN        NaN
# 4296  13.61  12.03     0.53    19.25  NaN        NaN
# 4297   6.52  17.70     0.55     7.47  NaN        NaN
# 4298   4.71  12.72     0.40     4.36  NaN        NaN

# %%
city_list = ['Delhi', 'Bengaluru','Kolkata']

# %%
city1_df = df[df['City'] == city_list[0]]
city1_df.head()
# Out:
#         City        Date   PM2.5    PM10     NO    NO2     NOx     NH3     CO  \
# 10229  Delhi  2015-01-01  313.22  607.98  69.16  36.39  110.59   33.85  15.20
# 10230  Delhi  2015-01-02  186.18  269.55  62.09  32.87   88.14   31.83   9.54
# 10231  Delhi  2015-01-03   87.18  131.90  25.73  30.31   47.95   69.55  10.61
# 10232  Delhi  2015-01-04  151.84  241.84  25.01  36.91   48.62  130.36  11.54
# 10233  Delhi  2015-01-05  146.60  219.13  14.01  34.92   38.25  122.88   9.20
#
#         SO2     O3  Benzene  Toluene    AQI AQI_Bucket
# 10229  9.25  41.68    14.36    24.86  472.0     Severe
# 10230  6.65  29.97    10.55    20.09  454.0     Severe
# 10231  2.65  19.71     3.91    10.23  143.0   Moderate
# 10232  4.63  25.36     4.26     9.71  319.0  Very Poor
# 10233  3.33  23.20     2.80     6.21  325.0  Very Poor

# %%
city1_df.shape
# Out:
# (2009, 15)

# %%
city3_df = df[df['City'] == city_list[2]]
city3_df.shape
# Out:
# (814, 15)

# %%
city2_df = df[df['City'] == city_list[1]]
city2_df.head()
# Out:
#            City        Date  PM2.5  PM10     NO    NO2    NOx    NH3     CO  \
# 4294  Bengaluru  2015-01-01    NaN   NaN   3.26  17.33  10.88  20.36   0.33
# 4295  Bengaluru  2015-01-02    NaN   NaN   6.05  19.73  14.14  23.74   1.35
# 4296  Bengaluru  2015-01-03    NaN   NaN  11.91  19.88  20.72   4.32  17.40
# 4297  Bengaluru  2015-01-04    NaN   NaN   7.45  21.61  16.88   0.87   5.05
# 4298  Bengaluru  2015-01-05    NaN   NaN   9.52  22.17  21.76  31.38   1.83
#
#         SO2     O3  Benzene  Toluene  AQI AQI_Bucket
# 4294   3.54  10.73     0.56     4.64  NaN        NaN
# 4295   3.97  22.77     0.65     5.31  NaN        NaN
# 4296  13.61  12.03     0.53    19.25  NaN        NaN
# 4297   6.52  17.70     0.55     7.47  NaN        NaN
# 4298   4.71  12.72     0.40     4.36  NaN        NaN

# %%
city3_df.head()
# Out:
#           City        Date  PM2.5   PM10    NO    NO2    NOx   NH3    CO  \
# 19032  Kolkata  2018-04-10  34.38  57.00   NaN  40.97    NaN  2.52  1.00
# 19033  Kolkata  2018-04-11  29.00  50.87  3.26  34.03  45.29  3.59  0.98
# 19034  Kolkata  2018-04-12  21.70  43.04  3.49  39.49  42.54  3.77  0.73
# 19035  Kolkata  2018-04-13  23.09  46.49  3.69  33.03  36.72  3.88  0.98
# 19036  Kolkata  2018-04-14  21.56  42.10  2.81  26.62  29.43  4.22  1.00
#
#          SO2     O3  Benzene  Toluene   AQI    AQI_Bucket
# 19032  25.46    NaN      NaN      NaN   NaN           NaN
# 19033  10.32  30.99     4.64     0.88  73.0  Satisfactory
# 19034    NaN  43.72     5.33     1.76  60.0  Satisfactory
# 19035    NaN  41.65     6.78     2.23  74.0  Satisfactory
# 19036    NaN  44.07     5.09     2.33  83.0  Satisfactory

# %%
final_df = pd.concat([city1_df,city2_df,city3_df])
final_df.head()
# Out:
#         City        Date   PM2.5    PM10     NO    NO2     NOx     NH3     CO  \
# 10229  Delhi  2015-01-01  313.22  607.98  69.16  36.39  110.59   33.85  15.20
# 10230  Delhi  2015-01-02  186.18  269.55  62.09  32.87   88.14   31.83   9.54
# 10231  Delhi  2015-01-03   87.18  131.90  25.73  30.31   47.95   69.55  10.61
# 10232  Delhi  2015-01-04  151.84  241.84  25.01  36.91   48.62  130.36  11.54
# 10233  Delhi  2015-01-05  146.60  219.13  14.01  34.92   38.25  122.88   9.20
#
#         SO2     O3  Benzene  Toluene    AQI AQI_Bucket
# 10229  9.25  41.68    14.36    24.86  472.0     Severe
# 10230  6.65  29.97    10.55    20.09  454.0     Severe
# 10231  2.65  19.71     3.91    10.23  143.0   Moderate
# 10232  4.63  25.36     4.26     9.71  319.0  Very Poor
# 10233  3.33  23.20     2.80     6.21  325.0  Very Poor

# %%
final_df.shape
# Out:
# (4832, 15)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4832 entries, 10229 to 19845
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        4832 non-null   object
#  1   Date        4832 non-null   object
#  2   PM2.5       4629 non-null   float64
#  3   PM10        4340 non-null   float64
#  4   NO          4798 non-null   float64
#  5   NO2         4799 non-null   float64
#  6   NOx         4827 non-null   float64
#  7   NH3         4620 non-null   float64
#  8   CO          4821 non-null   float64
#  9   SO2         4654 non-null   float64
#  10  O3          4554 non-null   float64
#  11  Benzene     4565 non-null   float64
#  12  Toluene     4738 non-null   float64
#  13  AQI         4663 non-null   float64
#  14  AQI_Bucket  4663 non-null   object
# dtypes: float64(12), object(3)
# memory usage: 604.0+ KB

# %%
final_df.isnull().sum()
# Out:
# City            0
# Date            0
# PM2.5         203
# PM10          492
# NO             34
# NO2            33
# NOx             5
# NH3           212
# CO             11
# SO2           178
# O3            278
# Benzene       267
# Toluene        94
# AQI           169
# AQI_Bucket    169
# dtype: int64

# %%
final_df['PM2.5']=final_df['PM2.5'].fillna(final_df['PM2.5'].mode()[0])
final_df['PM2.5'].isnull().sum()
# Out:
# 0

# %%
final_df['PM2.5']=final_df['PM2.5'].fillna(final_df['PM2.5'].mode()[0])
final_df['PM10']=final_df['PM10'].fillna(final_df['PM10'].mode()[0])
final_df['NO']=final_df['NO'].fillna(final_df['NO'].mean())
final_df['NO2']=final_df['NO2'].fillna(final_df['NO2'].mean())
final_df['NOx']=final_df['NOx'].fillna(final_df['NOx'].mean())
final_df['NH3']=final_df['NH3'].fillna(final_df['NH3'].mode()[0])
final_df['CO']=final_df['CO'].fillna(final_df['CO'].mean())
final_df['SO2']=final_df['SO2'].fillna(final_df['SO2'].mean())
final_df['O3']=final_df['O3'].fillna(final_df['O3'].mean())
final_df['Benzene']=final_df['Benzene'].fillna(final_df['Benzene'].mean())
final_df['Toluene']=final_df['Toluene'].fillna(final_df['Toluene'].mean())
final_df['AQI']=final_df['AQI'].fillna(final_df['AQI'].mean())
final_df.isnull().sum()
# Out:
# City            0
# Date            0
# PM2.5           0
# PM10            0
# NO              0
# NO2             0
# NOx             0
# NH3             0
# CO              0
# SO2             0
# O3              0
# Benzene         0
# Toluene         0
# AQI             0
# AQI_Bucket    169
# dtype: int64

# %%
##Fetaure Engineering Process
final_df['Date1']=final_df['Date'].str.split('-').str[2]
final_df['Month']=final_df['Date'].str.split('-').str[1]
final_df['Year']=final_df['Date'].str.split('-').str[0]

# %%
final_df.head()
# Out:
#         City        Date   PM2.5    PM10     NO    NO2     NOx     NH3     CO  \
# 10229  Delhi  2015-01-01  313.22  607.98  69.16  36.39  110.59   33.85  15.20
# 10230  Delhi  2015-01-02  186.18  269.55  62.09  32.87   88.14   31.83   9.54
# 10231  Delhi  2015-01-03   87.18  131.90  25.73  30.31   47.95   69.55  10.61
# 10232  Delhi  2015-01-04  151.84  241.84  25.01  36.91   48.62  130.36  11.54
# 10233  Delhi  2015-01-05  146.60  219.13  14.01  34.92   38.25  122.88   9.20
#
#         SO2     O3  Benzene  Toluene    AQI AQI_Bucket Date1 Month  Year
# 10229  9.25  41.68    14.36    24.86  472.0     Severe    01    01  2015
# 10230  6.65  29.97    10.55    20.09  454.0     Severe    02    01  2015
# 10231  2.65  19.71     3.91    10.23  143.0   Moderate    03    01  2015
# 10232  4.63  25.36     4.26     9.71  319.0  Very Poor    04    01  2015
# 10233  3.33  23.20     2.80     6.21  325.0  Very Poor    05    01  2015

# %%
final_df.drop('Date',axis = 1, inplace = True)

# %%
final_df.head()
# Out:
#         City   PM2.5    PM10     NO    NO2     NOx     NH3     CO   SO2  \
# 10229  Delhi  313.22  607.98  69.16  36.39  110.59   33.85  15.20  9.25
# 10230  Delhi  186.18  269.55  62.09  32.87   88.14   31.83   9.54  6.65
# 10231  Delhi   87.18  131.90  25.73  30.31   47.95   69.55  10.61  2.65
# 10232  Delhi  151.84  241.84  25.01  36.91   48.62  130.36  11.54  4.63
# 10233  Delhi  146.60  219.13  14.01  34.92   38.25  122.88   9.20  3.33
#
#           O3  Benzene  Toluene    AQI AQI_Bucket Date1 Month  Year
# 10229  41.68    14.36    24.86  472.0     Severe    01    01  2015
# 10230  29.97    10.55    20.09  454.0     Severe    02    01  2015
# 10231  19.71     3.91    10.23  143.0   Moderate    03    01  2015
# 10232  25.36     4.26     9.71  319.0  Very Poor    04    01  2015
# 10233  23.20     2.80     6.21  325.0  Very Poor    05    01  2015

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4832 entries, 10229 to 19845
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        4832 non-null   object
#  1   PM2.5       4832 non-null   float64
#  2   PM10        4832 non-null   float64
#  3   NO          4832 non-null   float64
#  4   NO2         4832 non-null   float64
#  5   NOx         4832 non-null   float64
#  6   NH3         4832 non-null   float64
#  7   CO          4832 non-null   float64
#  8   SO2         4832 non-null   float64
#  9   O3          4832 non-null   float64
#  10  Benzene     4832 non-null   float64
#  11  Toluene     4832 non-null   float64
#  12  AQI         4832 non-null   float64
#  13  AQI_Bucket  4663 non-null   object
#  14  Date1       4832 non-null   object
#  15  Month       4832 non-null   object
#  16  Year        4832 non-null   object
# dtypes: float64(12), object(5)
# memory usage: 679.5+ KB

# %%
final_df['Date1'] = final_df['Date1'].astype(int)
final_df['Month'] = final_df['Month'].astype(int)
final_df['Year'] = final_df['Year'].astype(int)
final_df['PM2.5'] = final_df['PM2.5'].astype(int)
final_df['PM10'] = final_df['PM10'].astype(int)
final_df['NO'] = final_df['NO'].astype(int)
final_df['NO2'] = final_df['NO2'].astype(int)
final_df['NOx'] = final_df['NOx'].astype(int)
final_df['NH3'] = final_df['NH3'].astype(int)
final_df['CO'] = final_df['CO'].astype(int)
final_df['SO2'] = final_df['SO2'].astype(int)
final_df['O3'] = final_df['O3'].astype(int)
final_df['Benzene'] = final_df['Benzene'].astype(int)
final_df['Toluene'] = final_df['Toluene'].astype(int)
final_df['AQI'] = final_df['AQI'].astype(int)
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4832 entries, 10229 to 19845
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        4832 non-null   object
#  1   PM2.5       4832 non-null   int32
#  2   PM10        4832 non-null   int32
#  3   NO          4832 non-null   int32
#  4   NO2         4832 non-null   int32
#  5   NOx         4832 non-null   int32
#  6   NH3         4832 non-null   int32
#  7   CO          4832 non-null   int32
#  8   SO2         4832 non-null   int32
#  9   O3          4832 non-null   int32
#  10  Benzene     4832 non-null   int32
#  11  Toluene     4832 non-null   int32
#  12  AQI         4832 non-null   int32
#  13  AQI_Bucket  4663 non-null   object
#  14  Date1       4832 non-null   int32
#  15  Month       4832 non-null   int32
#  16  Year        4832 non-null   int32
# dtypes: int32(15), object(2)
# memory usage: 396.4+ KB

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
final_df['City'] = labelencoder.fit_transform(final_df['City'])
final_df.head()
# Out:
#        City  PM2.5  PM10  NO  NO2  NOx  NH3  CO  SO2  O3  Benzene  Toluene  \
# 10229     1    313   607  69   36  110   33  15    9  41       14       24
# 10230     1    186   269  62   32   88   31   9    6  29       10       20
# 10231     1     87   131  25   30   47   69  10    2  19        3       10
# 10232     1    151   241  25   36   48  130  11    4  25        4        9
# 10233     1    146   219  14   34   38  122   9    3  23        2        6
#
#        AQI AQI_Bucket  Date1  Month  Year
# 10229  472     Severe      1      1  2015
# 10230  454     Severe      2      1  2015
# 10231  143   Moderate      3      1  2015
# 10232  319  Very Poor      4      1  2015
# 10233  325  Very Poor      5      1  2015

# %%
final_df['AQI_Bucket'] = labelencoder.fit_transform(final_df['AQI_Bucket'])

# %%
final_df.head()
# Out:
#        City  PM2.5  PM10  NO  NO2  NOx  NH3  CO  SO2  O3  Benzene  Toluene  \
# 10229     1    313   607  69   36  110   33  15    9  41       14       24
# 10230     1    186   269  62   32   88   31   9    6  29       10       20
# 10231     1     87   131  25   30   47   69  10    2  19        3       10
# 10232     1    151   241  25   36   48  130  11    4  25        4        9
# 10233     1    146   219  14   34   38  122   9    3  23        2        6
#
#        AQI  AQI_Bucket  Date1  Month  Year
# 10229  472           4      1      1  2015
# 10230  454           4      2      1  2015
# 10231  143           1      3      1  2015
# 10232  319           5      4      1  2015
# 10233  325           5      5      1  2015

# %%
cols = list(final_df.columns)
cols[13], cols[14] = cols[14], cols[13]
final_df = final_df[cols]
final_df.head()
# Out:
#        City  PM2.5  PM10  NO  NO2  NOx  NH3  CO  SO2  O3  Benzene  Toluene  \
# 10229     1    313   607  69   36  110   33  15    9  41       14       24
# 10230     1    186   269  62   32   88   31   9    6  29       10       20
# 10231     1     87   131  25   30   47   69  10    2  19        3       10
# 10232     1    151   241  25   36   48  130  11    4  25        4        9
# 10233     1    146   219  14   34   38  122   9    3  23        2        6
#
#        AQI  Date1  AQI_Bucket  Month  Year
# 10229  472      1           4      1  2015
# 10230  454      2           4      1  2015
# 10231  143      3           1      1  2015
# 10232  319      4           5      1  2015
# 10233  325      5           5      1  2015

# %%
cols[14], cols[15] = cols[15], cols[14]
final_df = final_df[cols]
final_df.head(2)
# Out:
#        City  PM2.5  PM10  NO  NO2  NOx  NH3  CO  SO2  O3  Benzene  Toluene  \
# 10229     1    313   607  69   36  110   33  15    9  41       14       24
# 10230     1    186   269  62   32   88   31   9    6  29       10       20
#
#        AQI  Date1  Month  AQI_Bucket  Year
# 10229  472      1      1           4  2015
# 10230  454      2      1           4  2015

# %%
cols[15], cols[16] = cols[16], cols[15]
final_df = final_df[cols]
final_df.head()
# Out:
#        City  PM2.5  PM10  NO  NO2  NOx  NH3  CO  SO2  O3  Benzene  Toluene  \
# 10229     1    313   607  69   36  110   33  15    9  41       14       24
# 10230     1    186   269  62   32   88   31   9    6  29       10       20
# 10231     1     87   131  25   30   47   69  10    2  19        3       10
# 10232     1    151   241  25   36   48  130  11    4  25        4        9
# 10233     1    146   219  14   34   38  122   9    3  23        2        6
#
#        AQI  Date1  Month  Year  AQI_Bucket
# 10229  472      1      1  2015           4
# 10230  454      2      1  2015           4
# 10231  143      3      1  2015           1
# 10232  319      4      1  2015           5
# 10233  325      5      1  2015           5

# %%
cols[12], cols[13] = cols[13], cols[12]
final_df = final_df[cols]
final_df.head()
# Out:
#        City  PM2.5  PM10  NO  NO2  NOx  NH3  CO  SO2  O3  Benzene  Toluene  \
# 10229     1    313   607  69   36  110   33  15    9  41       14       24
# 10230     1    186   269  62   32   88   31   9    6  29       10       20
# 10231     1     87   131  25   30   47   69  10    2  19        3       10
# 10232     1    151   241  25   36   48  130  11    4  25        4        9
# 10233     1    146   219  14   34   38  122   9    3  23        2        6
#
#        Date1  AQI  Month  Year  AQI_Bucket
# 10229      1  472      1  2015           4
# 10230      2  454      1  2015           4
# 10231      3  143      1  2015           1
# 10232      4  319      1  2015           5
# 10233      5  325      1  2015           5

# %%
cols[13], cols[14] = cols[14], cols[13]
final_df = final_df[cols]
final_df.head()
# Out:
#        City  PM2.5  PM10  NO  NO2  NOx  NH3  CO  SO2  O3  Benzene  Toluene  \
# 10229     1    313   607  69   36  110   33  15    9  41       14       24
# 10230     1    186   269  62   32   88   31   9    6  29       10       20
# 10231     1     87   131  25   30   47   69  10    2  19        3       10
# 10232     1    151   241  25   36   48  130  11    4  25        4        9
# 10233     1    146   219  14   34   38  122   9    3  23        2        6
#
#        Date1  Month  AQI  Year  AQI_Bucket
# 10229      1      1  472  2015           4
# 10230      2      1  454  2015           4
# 10231      3      1  143  2015           1
# 10232      4      1  319  2015           5
# 10233      5      1  325  2015           5

# %%
cols[14], cols[15] = cols[15], cols[14]
final_df = final_df[cols]
final_df.head()
# Out:
#        City  PM2.5  PM10  NO  NO2  NOx  NH3  CO  SO2  O3  Benzene  Toluene  \
# 10229     1    313   607  69   36  110   33  15    9  41       14       24
# 10230     1    186   269  62   32   88   31   9    6  29       10       20
# 10231     1     87   131  25   30   47   69  10    2  19        3       10
# 10232     1    151   241  25   36   48  130  11    4  25        4        9
# 10233     1    146   219  14   34   38  122   9    3  23        2        6
#
#        Date1  Month  Year  AQI  AQI_Bucket
# 10229      1      1  2015  472           4
# 10230      2      1  2015  454           4
# 10231      3      1  2015  143           1
# 10232      4      1  2015  319           5
# 10233      5      1  2015  325           5

# %%
X = final_df.iloc[:,0:15]
X.shape
# Out:
# (4832, 15)

# %%
y_reg = final_df['AQI']

# %%
y_reg.head()
# Out:
# 10229    472
# 10230    454
# 10231    143
# 10232    319
# 10233    325
# Name: AQI, dtype: int32

# %%
y_class = final_df['AQI_Bucket']
y_class.head(2)
# Out:
# 10229    4
# 10230    4
# Name: AQI_Bucket, dtype: int32

# %%
from sklearn.model_selection import train_test_split
xr_train,xr_test,yr_train,yr_test=train_test_split(X,y_reg,test_size=0.2,random_state=42)

# %%
from sklearn.model_selection import train_test_split
xc_train,xc_test,yc_train,yc_test=train_test_split(X,y_class,test_size=0.2,random_state=42)

# %% [markdown]
# ## First Algorithm Naive Bayes(Model 1)

# %%
from sklearn.naive_bayes import MultinomialNB
classifier = MultinomialNB(alpha=0.1)
classifier.fit(xc_train, yc_train)
# Out:
# MultinomialNB(alpha=0.1)

# %%
yc_pred = classifier.predict(xc_test)

# %%
accuracy, precision, recall, f1 = get_metrics(yc_test, yc_pred)
print("accuracy = %.3f \nprecision = %.3f \nrecall = %.3f \nf1 = %.3f" % (accuracy, precision, recall, f1))
# Out:
# accuracy = 0.634
# precision = 0.667
# recall = 0.634
# f1 = 0.641

# %%
# Get predicted probabilities for each class
yc_pred_proba = classifier.predict_proba(xc_test)

# Compute ROC curve for each class
fpr = {}
tpr = {}
roc_auc = {}
n_classes = len(classifier.classes_)
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(yc_test, yc_pred_proba[:, i], pos_label=i)
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curve for each class
plt.figure(figsize=(10, 6))
colors = ['blue', 'green', 'red', 'cyan', 'magenta', 'yellow', 'black', 'purple', 'orange', 'pink']
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], color=colors[i], lw=2, label='Class %s (AUC = %0.2f)' % (i, roc_auc[i]))

plt.plot([0, 1], [0, 1], color='navy', linestyle='--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Naive Bayes Classifier')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Second Algorithm Random Forest Regressor(Model 2)

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score,  mean_absolute_percentage_error
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)
rf_regressor.fit(xr_train, yr_train)
yr_pred = rf_regressor.predict(xr_test)
mse = mean_squared_error(yr_test, yr_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 878.0872117890383

# %%
r2 = r2_score(yr_test, yr_pred)
print(f"R² Score: {r2:.4f}")
# Out:
# R² Score: 0.9423

# %%
mape =  mean_absolute_percentage_error(yr_test,yr_pred)
accuracy = 100 - (mape * 100)
print(f"Percentage Accuracy: {accuracy:.2f}%")
# Out:
# Percentage Accuracy: 86.99%

# %% [markdown]
# ## Third Algorthm XGBoost Regressor(Model 3)

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error
from xgboost import XGBRegressor
model = XGBRegressor()
model.fit(xr_train, yr_train)
yr_pred = model.predict(xr_test)
mae = mean_absolute_error(yr_test, yr_pred)
mse = mean_squared_error(yr_test, yr_pred)
rmse = np.sqrt(mse)
mape = mean_absolute_percentage_error(yr_test, yr_pred)
accuracy = 100 - (mape * 100)
r2 = r2_score(yr_test, yr_pred)

accuracy_matrix = pd.DataFrame({
    'Metric': ['MAPE-based Accuracy (%)', 'MAE', 'MSE', 'RMSE', 'R² Score'],
    'Value': [accuracy, mae, mse, rmse, r2]
})

print(accuracy_matrix)
# Out:
#                     Metric       Value
# 0  MAPE-based Accuracy (%)   86.355466
# 1                      MAE   19.917833
# 2                      MSE  965.057129
# 3                     RMSE   31.065369
# 4                 R² Score    0.936607

# %% [markdown]
# ## Fourth Algoruthm XGBosst Classifiction

# %%
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBClassifier
model = XGBClassifier()
model.fit(xc_train, yc_train)
yc_pred = model.predict(xc_test)
accuracy = accuracy_score(yc_test, yc_pred)
print('Accuracy:', accuracy)
# Out:
# Accuracy: 0.7973112719751809

# %%
accuracy_xgb,precision_xgb,recall_xgb,f1_xgb=get_metrics(yc_test,yc_pred)
print("accuracy_xgb = %.3f \nprecision_xgb = %.3f \nrecall_xgb = %.3f \nf1_xgb = %.3f" % (accuracy_xgb, precision_xgb, recall_xgb, f1_xgb))
# Out:
# accuracy_xgb = 0.797
# precision_xgb = 0.798
# recall_xgb = 0.797
# f1_xgb = 0.796

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Get predicted probabilities for each class
yc_pred_proba = model.predict_proba(xc_test)

fpr = {}
tpr = {}
roc_auc = {}
n_classes = len(model.classes_)
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(yc_test, yc_pred_proba[:, i], pos_label=i)
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure(figsize=(10, 6))
colors = ['blue', 'green', 'red', 'cyan', 'magenta', 'yellow', 'black', 'purple', 'orange', 'pink']
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], color=colors[i], lw=2, label='Class %s (AUC = %0.2f)' % (i, roc_auc[i]))

plt.plot([0, 1], [0, 1], color='navy', linestyle='--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for XGBoost Classifier')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Fifth Algorithm SVR

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd

sc = StandardScaler()


xr_train = sc.fit_transform(xr_train)
xr_test = sc.transform(xr_test)

yr_train = sc.fit_transform(yr_train.values.reshape(-1, 1)).ravel()

# Train SVR model
model = SVR(kernel='rbf', C=100, gamma=0.1, epsilon=0.1)
model.fit(xr_train, yr_train)

# Predictions (need to inverse transform)
yr_pred = model.predict(xr_test)
yr_pred = sc.inverse_transform(yr_pred.reshape(-1, 1)).ravel()

# Metrics
mae = mean_absolute_error(yr_test, yr_pred)
mse = mean_squared_error(yr_test, yr_pred)
rmse = np.sqrt(mse)
mape = mean_absolute_percentage_error(yr_test, yr_pred)
accuracy = 100 - (mape * 100)
r2 = r2_score(yr_test, yr_pred)

# Accuracy Matrix
accuracy_matrix = pd.DataFrame({
    'Metric': ['MAPE-based Accuracy (%)', 'MAE', 'MSE', 'RMSE', 'R² Score'],
    'Value': [accuracy, mae, mse, rmse, r2]
})

print(accuracy_matrix)
# Out:
#                     Metric        Value
# 0  MAPE-based Accuracy (%)    83.593556
# 1                      MAE    25.096021
# 2                      MSE  1513.725011
# 3                     RMSE    38.906619
# 4                 R² Score     0.900567
